# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from synthetic_task.plot_results import load_results, plot_total_loss_vs_method_by_ydim, plot_total_time_vs_method_by_ydim, plot_total_time_vs_ydim_for_methods

# %%
sns.set_theme(style="whitegrid", context="talk")
palette = sns.color_palette()

# %%
# PLOT GENERAL TASK -- SOC

batch_size = 8
SOC_DIR = f"../synthetic_results_general_{batch_size}"
METHODS = [
    "cvxpylayer",
    "lpgd",
    "bpqp",
    "ffocp_eq",
]
METHODS_LEGEND = {
    "cvxpylayer": "CvxpyLayer",
    "lpgd": "LPGD",
    "bpqp": "BPQP",
    "ffocp_eq": "FFOCP",
}

METHODS_STEPS = [method+"_steps" for method in METHODS]

method_order = [METHODS_LEGEND[m] for m in METHODS]

markers = ["o", "s", "D", "^", "v", "x"]
markers_dict = {method: markers[i] for i, method in enumerate(method_order)}

LINEWIDTH = 1.5

# %%
df = load_results(base_dir=SOC_DIR, methods=METHODS, methods_legend=METHODS_LEGEND)
df = df.rename(columns=lambda c: c.strip() if isinstance(c, str) else c)
df["method"] = pd.Categorical(df["method"], categories=method_order, ordered=True)
# Out:
# method:  cvxpylayer
# method:  lpgd
# method:  bpqp
# method:  ffocp_eq
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:72: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(dfs, ignore_index=True, sort=False)

# %%
plot_total_time_vs_method_by_ydim(df, SOC_DIR, ('forward_time','backward_time'), tag="syn")
# Out:
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()

# %%
# plot all ydim
selected_methods = ["FFOCP", "BPQP"]
plot_total_time_vs_ydim_for_methods(
    df,
    methods_subset=selected_methods,
    time_names=('forward_time', 'backward_time'),
    plot_path=SOC_DIR,
    plot_name_tag="syn_steps_solve_ffocp_bpqp"
)
# Out:
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:188: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(["method", "ydim"])[list(time_names)]

# %%
df = load_results(base_dir=SOC_DIR, methods=METHODS_STEPS)
df = df.rename(columns=lambda c: c.strip() if isinstance(c, str) else c)
df["method"] = pd.Categorical(df["method"], categories=method_order, ordered=True)
# Out:
# method:  cvxpylayer
# method:  lpgd
# method:  bpqp
# method:  ffocp_eq

# %%
df[df["method"] == "FFOCP"].ydim.unique()
# Out:
# array([1000,  200,  300,  400,  500,  600,  700,  800,  900])

# %%
plot_total_loss_vs_method_by_ydim(df, SOC_DIR)
# Out:
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()

# %%
# PLOT SYNTHETIC TASK -- QP

batch_size = 8
QP_DIR = f"../synthetic_results_{batch_size}"
METHODS = [
    "cvxpylayer",
    "qpth",
    "lpgd",
    "bpqp",
    "dqp",
    # "altdiff",
    "ffoqp_eq_schur",
    "ffocp_eq",
]
METHODS_LEGEND = {
    "cvxpylayer": "CvxpyLayer",
    "qpth": "qpth",
    "lpgd": "LPGD",
    "bpqp": "BPQP",
    "dqp": "dQP",
    # "altdiff": "AltDiff",
    "ffoqp_eq_schur": "FFOQP",
    "ffocp_eq": "FFOCP",
}

METHODS_STEPS = [method+"_steps" for method in METHODS]

method_order = [METHODS_LEGEND[m] for m in METHODS]

markers = ["o", "s", "D", "^", "v", "x", "P", "s"]
markers_dict = {method: markers[i] for i, method in enumerate(method_order)}

LINEWIDTH = 1.5

# %%
df = load_results(base_dir=QP_DIR, methods=METHODS, methods_legend=METHODS_LEGEND)
df = df.rename(columns=lambda c: c.strip() if isinstance(c, str) else c)
df["method"] = pd.Categorical(df["method"], categories=method_order, ordered=True)
# Out:
# method:  cvxpylayer
# method:  qpth
# method:  lpgd
# method:  bpqp
# method:  dqp
# method:  ffoqp_eq_schur
# method:  ffocp_eq
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:72: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(dfs, ignore_index=True, sort=False)

# %%
df[df["method"] == "FFOQP"]
# Out:
#     epoch  train_ts_loss  test_ts_loss  train_df_loss  test_df_loss  \
# 177     0       2.022251           0.0      -0.470483           0.0
# 178     0       2.019125           0.0      -0.470648           0.0
# 179     0       2.018426           0.0      -0.470326           0.0
# 180     0       2.024847           0.0      -0.470489           0.0
# 181     0       2.011752           0.0      -0.470854           0.0
# 182     0      18.086056           0.0      -0.470948           0.0
# 183     0      17.492134           0.0      -0.466009           0.0
# 184     0      17.062976           0.0      -0.465557           0.0
# 185     0      18.355709           0.0      -0.468976           0.0
# 186     0      16.960707           0.0      -0.466620           0.0
# 187     0       7.910639           0.0      -0.463971           0.0
# 188     0       7.720632           0.0      -0.462518           0.0
# 189     0       8.373011           0.0      -0.461273           0.0
# 190     0       8.756889           0.0      -0.462116           0.0
# 191     0       9.262113           0.0      -0.460296           0.0
# 192     0       1.976473           0.0      -0.470650           0.0
# 193     0       1.971683           0.0      -0.469227           0.0
# 194     0       1.987989           0.0      -0.470447           0.0
# 195     0       1.993113           0.0      -0.471174           0.0
# 196     0       1.988667           0.0      -0.470190           0.0
# 197     0       1.970201           0.0      -0.471296           0.0
# 198     0       1.957739           0.0      -0.470062           0.0
# 199     0       1.960787           0.0      -0.470992           0.0
# 200     0       1.976369           0.0      -0.471322           0.0
# 201     0       1.957962           0.0      -0.470786           0.0
# 202     0       1.947446           0.0      -0.470626           0.0
# 203     0       1.960718           0.0      -0.469574           0.0
# 204     0       1.935937           0.0      -0.470184           0.0
# 205     0       1.986730           0.0      -0.470721           0.0
# 206     0       1.973213           0.0      -0.470833           0.0
# 207     0       1.950182           0.0      -0.470108           0.0
# 208     0       1.962221           0.0      -0.470679           0.0
# 209     0       1.986353           0.0      -0.470412           0.0
# 210     0       1.942756           0.0      -0.471399           0.0
# 211     0       1.965501           0.0      -0.470732           0.0
# 212     0       1.991679           0.0      -0.470643           0.0
# 213     0       1.992535           0.0      -0.470451           0.0
# 214     0       1.995589           0.0      -0.471153           0.0
# 215     0       1.973228           0.0      -0.471012           0.0
# 216     0       1.971448           0.0      -0.470499           0.0
# 217     0       2.008492           0.0      -0.470659           0.0
# 218     0       2.000070           0.0      -0.470868           0.0
# 219     0       1.998534           0.0      -0.470715           0.0
# 220     0       2.005839           0.0      -0.470960           0.0
# 221     0       2.007123           0.0      -0.471161           0.0
#
#      forward_time  backward_time method  seed   n     lr  ydim
# 177    160.426657      47.148969  FFOQP     1 NaN  0.001  1000
# 178    161.273411      49.882841  FFOQP     2 NaN  0.001  1000
# 179    151.301033      46.942996  FFOQP     3 NaN  0.001  1000
# 180    150.692197      45.952870  FFOQP     4 NaN  0.001  1000
# 181    163.837943      50.228734  FFOQP     5 NaN  0.001  1000
# 182      9.284622       7.896209  FFOQP     1 NaN  0.001   200
# 183      8.994586       7.294591  FFOQP     2 NaN  0.001   200
# 184      8.793956       7.021729  FFOQP     3 NaN  0.001   200
# 185      8.811676       7.122147  FFOQP     4 NaN  0.001   200
# 186      8.765207       7.910513  FFOQP     5 NaN  0.001   200
# 187     15.473215       4.343293  FFOQP     1 NaN  0.001   300
# 188     16.591839       5.063000  FFOQP     2 NaN  0.001   300
# 189     15.627411       4.612822  FFOQP     3 NaN  0.001   300
# 190     15.309109       4.847127  FFOQP     4 NaN  0.001   300
# 191     15.563855       4.895429  FFOQP     5 NaN  0.001   300
# 192     28.344851      13.864420  FFOQP     1 NaN  0.001   400
# 193     30.470888      16.627100  FFOQP     2 NaN  0.001   400
# 194     28.641650      12.223557  FFOQP     3 NaN  0.001   400
# 195     28.080737      13.041409  FFOQP     4 NaN  0.001   400
# 196     30.149175      13.199767  FFOQP     5 NaN  0.001   400
# 197     44.830483      19.222894  FFOQP     1 NaN  0.001   500
# 198     48.191841      20.310199  FFOQP     2 NaN  0.001   500
# 199     44.687880      20.360677  FFOQP     3 NaN  0.001   500
# 200     46.698743      21.821569  FFOQP     4 NaN  0.001   500
# 201     44.612615      20.620520  FFOQP     5 NaN  0.001   500
# 202     67.971698      24.638906  FFOQP     1 NaN  0.001   600
# 203     67.806608      23.998150  FFOQP     2 NaN  0.001   600
# 204     63.133151      21.821224  FFOQP     3 NaN  0.001   600
# 205     63.235822      21.500700  FFOQP     4 NaN  0.001   600
# 206     62.842411      21.902497  FFOQP     5 NaN  0.001   600
# 207     89.667691      28.040715  FFOQP     1 NaN  0.001   700
# 208     89.291832      28.281360  FFOQP     2 NaN  0.001   700
# 209     83.464025      25.982363  FFOQP     3 NaN  0.001   700
# 210     83.403342      25.534204  FFOQP     4 NaN  0.001   700
# 211     90.882168      28.472410  FFOQP     5 NaN  0.001   700
# 212    116.112663      42.077729  FFOQP     1 NaN  0.001   800
# 213    111.933063      30.916547  FFOQP     2 NaN  0.001   800
# 214    104.510260      29.248914  FFOQP     3 NaN  0.001   800
# 215    113.234818      33.905232  FFOQP     4 NaN  0.001   800
# 216    104.135090      29.432138  FFOQP     5 NaN  0.001   800
# 217    135.493692      39.999884  FFOQP     1 NaN  0.001   900
# 218    135.584150      40.511247  FFOQP     2 NaN  0.001   900
# 219    128.411756      39.518944  FFOQP     3 NaN  0.001   900
# 220    138.161500      43.510129  FFOQP     4 NaN  0.001   900
# 221    126.561301      36.456376  FFOQP     5 NaN  0.001   900

# %%
plot_total_time_vs_method_by_ydim(df, QP_DIR, ('forward_time','backward_time'), tag="syn")
# Out:
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_method = df.groupby('method')[time_names].mean().reset_index()

# %%
# plot all ydim
selected_methods = ["FFOQP", "BPQP"]
plot_total_time_vs_ydim_for_methods(
    df,
    methods_subset=selected_methods,
    time_names=('forward_time', 'backward_time'),
    plot_path=QP_DIR,
    plot_name_tag="syn_steps_solve_ffocp_bpqp"
)
# Out:
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:188: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(["method", "ydim"])[list(time_names)]

# %%
df = load_results(base_dir=QP_DIR, methods=METHODS_STEPS)
df = df.rename(columns=lambda c: c.strip() if isinstance(c, str) else c)
df["method"] = pd.Categorical(df["method"], categories=method_order, ordered=True)
# Out:
# method:  cvxpylayer
# method:  qpth
# method:  lpgd
# method:  bpqp
# method:  dqp
# method:  ffoqp_eq_schur
# method:  ffocp_eq

# %%
plot_total_loss_vs_method_by_ydim(df, QP_DIR)
# Out:
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
# /storage/scratch1/9/zzhao628/FFOLayer/synthetic_task/plot_results.py:131: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_avg_epoch = df.groupby(['method', iteration_name])[[loss_metric_name]].mean().reset_index()
